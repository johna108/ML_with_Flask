# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

#sample dataset with multiple features
data = {
    'feature1': [10, 20, 30, 40, 50],
    'feature2': [5, 15, 30,32,50],
    'feature3': [100, 200, 300, 400, 500]
}

df = pd.DataFrame(data)
print("original DataFrame:")
print(df)


#initialize MinMaxSCaler
scaler = MinMaxScaler()
#normalize the dataset
normalized_data = scaler.fit_transform(df)
#create a new Dataframe with normalized  values
normalized_df = pd.DataFrame(normalized_data, columns=df.columns)
print("\nNormalized DataFrame:")
print(normalized_df)

#Standardize the dataset
standardized_data = (df - df.mean()) / df.std()
standardized_data.fillna(0, inplace=True)
print("\nStandardized DataFrame:")
print(standardized_data)
# Out:
# original DataFrame:
#    feature1  feature2  feature3
# 0        10         5       100
# 1        20        15       200
# 2        30        30       300
# 3        40        32       400
# 4        50        50       500
#
# Normalized DataFrame:
#    feature1  feature2  feature3
# 0      0.00  0.000000      0.00
# 1      0.25  0.222222      0.25
# 2      0.50  0.555556      0.50
# 3      0.75  0.600000      0.75
# 4      1.00  1.000000      1.00
#
# Standardized DataFrame:
#    feature1  feature2  feature3
# 0 -1.264911 -1.241127 -1.264911
# 1 -0.632456 -0.661161 -0.632456
# 2  0.000000  0.208788  0.000000
# 3  0.632456  0.324781  0.632456
# 4  1.264911  1.368720  1.264911
