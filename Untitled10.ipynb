# %%
import scipy.stats as stats

#define array of turtle weights for each samples
sample1 = [1,2,3,4,5,6]
sample2 = [2,3,5,7,8,9]

stats.ttest_ind(a=sample1,b=sample2)
print(df.head())
# Out:
#    col1  col2  col3
# 0     1     2     5
# 1     2     4     3
# 2     3     1     4
# 3     4     5     2
# 4     5     3     1
