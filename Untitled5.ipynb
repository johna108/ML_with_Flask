# %%
from google.colab import drive
drive.mount('content/sample_data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-cc112bd0da74> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('content/sample_data')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     202     normed = _os.path.normpath(mountpoint)
#     203     if '/' in normed and not _os.path.exists(_os.path.dirname(normed)):
# ...

# %%
employee =

# %%
e1=['arun',2,5,20000,'yes']
e2=['amla',3,5,31000,'no']
e3=['bala',4,6,24000,'yes']
e4=['sana',3,5,80000,'no']
e5=['petal',2,5,20000,'yes']
e6=['roshita',4,6,24000,'yes']
e7=['priya',3,5,31000,'no']
e8=['madhan',4,6,24000,'yes']
e9=['akhil',3,5,80000,'no']
e11=['vivek',2,5,20000,'yes']
e12=['tarun',3,5,31000,'no']
e13=['karthik',4,6,24000,'yes']
e14=['gaurav',3,5,80000,'no']
