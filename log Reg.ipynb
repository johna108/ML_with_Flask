# %%
import numpy as np
from sklearn.metrics import confusion_matrix
y_true = np.array([0] * 128 + [1] * 86)
y_pred = np.array([0] * 104 + [1] * 24 + [0] * 26 + [1] * 60)
cm = confusion_matrix(y_true, y_pred)
cm
# Out:
# array([[104,  24],
#        [ 26,  60]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_true, y_pred)
# Out:
# 0.7663551401869159

# %%
from sklearn.metrics import precision_score
precision_score(y_true, y_pred)
# Out:
# 0.7142857142857143

# %%
from sklearn.metrics import recall_score
recall_score(y_true, y_pred)
# Out:
# 0.6976744186046512

# %%
from sklearn import f1_score
f1_score(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-683c5ee84122> in <cell line: 0>()
# ----> 1 from sklearn import f1_score
#       2 f1_score(y_true, y_pred)
#
# ImportError: cannot import name 'f1_score' from 'sklearn' (/usr/local/lib/python3.11/dist-packages/sklearn/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
