# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file = '/content/drive/MyDrive/Claimants_Test.csv'
df = pd.read_csv(file)
df.head()
# Out:
#    CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE
# 0        5         0       0       1.0         0    50.0
# 1        3         1       1       0.0         0    18.0
# 2       66         1       0       1.0         0     5.0
# 3       70         0       0       1.0         1    31.0
# 4       96         1       0       1.0         0    30.0

# %%
df.tail()
# Out:
#     CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE
# 28      607         1       0       1.0         0    40.0
# 29      630         0       0       1.0         0     NaN
# 30      640         1       1       1.0         0    16.0
# 31      640         1       0       1.0         0     NaN
# 32      685         1       0       1.0         0     9.0

# %%
df.drop(["CASENUM"], inplace=True, axis=1)
df.head()
# Out:
#    ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE
# 0         0       0       1.0         0    50.0
# 1         1       1       0.0         0    18.0
# 2         1       0       1.0         0     5.0
# 3         0       0       1.0         1    31.0
# 4         1       0       1.0         0    30.0

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE
# 0         0       0       1.0         0    50.0
# 1         1       1       0.0         0    18.0
# 2         1       0       1.0         0     5.0
# 3         0       0       1.0         1    31.0
# 4         1       0       1.0         0    30.0

# %%
#for vscode
import pandas as pd
import streamlit as st
from sklearn.linear_model import LogisticRegression
st.title('Model Deployment: Logistic regression')
st.sidebar.header('User Input Parameters')

def user_input_features():

    CLMSEX = st.sidebar.selectbox('Gender',('1','0'))

    CLMINSUR = st.sidebar.selectbox('Insurance',('1','0'))

    SEATBELT = st.sidebar.selectbox('SeatBelt',('1','0'))

    CLMAGE = st.sidebar.number_input("Insert the Age")

    LOSS = st.sidebar.number_input("Insert Loss")

    data = {'CLMSEX':CLMSEX,

            'CLMINSUR':CLMINSUR,

            'SEATBELT':SEATBELT,

            'CLMAGE':CLMAGE,

            'LOSS':LOSS}

    features = pd.DataFrame(data,index = [0])

    return features

# %%
df = user_input_features()
st.subheader('User Input parameters')
st.write(df)

claimants = pd.read_csv("claimants.csv")
claimants.drop(["CASENUM"], inplace=True, axis=1)
claimants = claimants.dropna()

X = claimants.iloc[:,[1,2,3,4]]
y = claimants.iloc[:,0]
clf = LogisticRegression()
clf.fit(X,y)
prediction = clf.predict(df)
st.subheader('Predicted Result')
st.write('Yes' if prediction[0][1] > 0.5 else 'No')

st.subheader('Prediction Probability')
st.write(clf.predict_proba(df)
